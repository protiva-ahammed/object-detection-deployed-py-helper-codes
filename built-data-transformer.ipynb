# %%
from super_gradients.training.dataloaders.dataloaders import coco_detection_yolo_format_train, coco_detection_yolo_format_val

BATCH_SIZE = 8
CLASSES = ['product']
CLASSES += [str(i) for i in range(80 - len(CLASSES))]

dataset_params = {
    'data_dir': "./archive",
    'train_images_dir':'resized640yolo/images/train',
    'train_labels_dir':'resized640yolo/labels/train',
    'val_images_dir':'resized640yolo/images/val',
    'val_labels_dir':'resized640yolo/labels/val',
    'test_images_dir':'resized640yolo/images/test',
    'test_labels_dir':'resized640yolo/labels/test',
    'classes': CLASSES
}

train_data0 = coco_detection_yolo_format_train(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['train_images_dir'],
        'labels_dir': dataset_params['train_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)

train_data1 = coco_detection_yolo_format_train(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['train_images_dir'],
        'labels_dir': dataset_params['train_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)

train_data2 = coco_detection_yolo_format_train(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['train_images_dir'],
        'labels_dir': dataset_params['train_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)


train_data3 = coco_detection_yolo_format_train(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['train_images_dir'],
        'labels_dir': dataset_params['train_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)

val_data = coco_detection_yolo_format_val(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['val_images_dir'],
        'labels_dir': dataset_params['val_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)

test_data = coco_detection_yolo_format_val(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['test_images_dir'],
        'labels_dir': dataset_params['test_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)
# Out:
# [2024-03-28 14:45:10] WARNING - yolo_format_detection.py - 1 images are note associated to any label file
# [2024-03-28 14:45:10] WARNING - yolo_format_detection.py - As a consequence, 314/315 images and 314/314 label files will be used.
# Caching annotations: 100%|███████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 7565.99it/s]
# [2024-03-28 14:45:10] WARNING - yolo_format_detection.py - 1 images are note associated to any label file
# [2024-03-28 14:45:10] WARNING - yolo_format_detection.py - As a consequence, 314/315 images and 314/314 label files will be used.
# Caching annotations: 100%|███████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 8873.19it/s]
# [2024-03-28 14:45:10] WARNING - yolo_format_detection.py - 1 images are note associated to any label file
# [2024-03-28 14:45:10] WARNING - yolo_format_detection.py - As a consequence, 314/315 images and 314/314 label files will be used.
# ...

# %%
train_data1.dataset.transforms
# Out:
# [DetectionMosaic('additional_samples_count': 3, 'non_empty_targets': False, 'prob': 1.0, 'input_dim': (640, 640), 'enable_mosaic': True, 'border_value': 114),
#  DetectionRandomAffine('additional_samples_count': 0, 'non_empty_targets': False, 'degrees': 10.0, 'translate': 0.1, 'scale': [0.1, 2], 'shear': 2.0, 'target_size': (640, 640), 'enable': True, 'filter_box_candidates': True, 'wh_thr': 2, 'ar_thr': 20, 'area_thr': 0.1, 'border_value': 114),
#  DetectionMixup('additional_samples_count': 1, 'non_empty_targets': True, 'input_dim': (640, 640), 'mixup_scale': [0.5, 1.5], 'prob': 1.0, 'enable_mixup': True, 'flip_prob': 0.5, 'border_value': 114),
#  DetectionHSV('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 1.0, 'hgain': 5, 'sgain': 30, 'vgain': 30, 'bgr_channels': (0, 1, 2), '_additional_channels_warned': False),
#  DetectionHorizontalFlip('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 0.5),
# ...

# %%
train_data2.dataset.transforms.pop(2)
# Out:
# DetectionMixup('additional_samples_count': 1, 'non_empty_targets': True, 'input_dim': (640, 640), 'mixup_scale': [0.5, 1.5], 'prob': 1.0, 'enable_mixup': True, 'flip_prob': 0.5, 'border_value': 114)

# %%
train_data3.dataset.transforms.pop(4)
# Out:
# DetectionHorizontalFlip('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 0.5)

# %%
train_data0.dataset.transforms.pop(2)
# Out:
# DetectionMixup('additional_samples_count': 1, 'non_empty_targets': True, 'input_dim': (640, 640), 'mixup_scale': [0.5, 1.5], 'prob': 1.0, 'enable_mixup': True, 'flip_prob': 0.5, 'border_value': 114)

# %%
train_data0.dataset.transforms.pop(3)
# Out:
# DetectionHorizontalFlip('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 0.5)

# %%
train_data0.dataset.plot(plot_transformed_data=True)

# %%
train_data1.dataset.plot(plot_transformed_data=True)

# %%
train_data3.dataset.plot(plot_transformed_data=True)

# %%
# ommiting 3->DetectionHSV('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 1.0, 'hgain': 5, 'sgain': 30, 'vgain': 30, 'bgr_channels': (0, 1, 2), 
#'_additional_channels_warned': False)
#data performance bad
train_data3.dataset.plot(plot_transformed_data=True)

# %%
# train_data0.dataset.transforms.pop(1)

# %%
train_data0.dataset.transforms
# Out:
# [DetectionMosaic('additional_samples_count': 3, 'non_empty_targets': False, 'prob': 1.0, 'input_dim': (640, 640), 'enable_mosaic': True, 'border_value': 114),
#  DetectionRandomAffine('additional_samples_count': 0, 'non_empty_targets': False, 'degrees': 10.0, 'translate': 0.1, 'scale': [0.1, 2], 'shear': 2.0, 'target_size': (640, 640), 'enable': True, 'filter_box_candidates': True, 'wh_thr': 2, 'ar_thr': 20, 'area_thr': 0.1, 'border_value': 114),
#  DetectionHSV('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 1.0, 'hgain': 5, 'sgain': 30, 'vgain': 30, 'bgr_channels': (0, 1, 2), '_additional_channels_warned': False),
#  DetectionPaddedRescale('additional_samples_count': 0, 'non_empty_targets': False, 'swap': (2, 0, 1), 'input_dim': (640, 640), 'pad_value': 114),
# ...

# %%
# from torch.utils.data import ConcatDataset
# from torch.utils.data import DataLoader

# dataset0 = train_data0.dataset
# dataset1 = train_data1.dataset
# dataset2 = train_data2.dataset
# dataset3 = train_data3.dataset

# # Concatenate datasets
# concatenated_dataset = ConcatDataset([dataset0, dataset1, dataset2, dataset3])

# # Now, create a new DataLoader using the concatenated dataset
# train_data = DataLoader(concatenated_dataset, batch_size=BATCH_SIZE ,shuffle=True)

# %%
# import torch

# def custom_collate_fn(batch):
#     # Find the maximum height and width in the batch
#     max_height = max(sample[0].shape[0] for sample in batch)
#     max_width = max(sample[0].shape[1] for sample in batch)

#     # Pad images to the maximum height and width
#     padded_images = []
#     targets = []
#     for image, target in batch:
#         # Convert the NumPy array to a PyTorch tensor for both image and target
#         image_tensor = torch.from_numpy(image)
#         target_tensor = torch.from_numpy(target)

#         # Pad the image
#         padded_image = torch.nn.functional.pad(image_tensor, (0, max_width - image_tensor.shape[1], 0, max_height - image_tensor.shape[0]))
#         padded_images.append(padded_image)
#         targets.append(target_tensor)

#     # Stack padded images into a single tensor
#     images = torch.stack(padded_images, dim=0)

#     # Stack targets into a single tensor
#     targets = torch.stack(targets, dim=0)

#     return images, targets

# # Now, when creating DataLoader, specify the custom collate function
# train_data = DataLoader(concatenated_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn)

# %%
# import torch
# from torchvision.transforms.functional import resize

# def custom_collate_fn(batch):
#     # Find the maximum height and width in the batch
#     max_height = max(sample[0].shape[0] for sample in batch)
#     max_width = max(sample[0].shape[1] for sample in batch)

#     # Define a fixed size for resizing
#     target_size = (max_height, max_width)

#     # Resize images to the maximum height and width
#     resized_images = []
#     targets = []
#     for image, target in batch:
#         # Convert the NumPy array to a PyTorch tensor for both image and target
#         image_tensor = torch.from_numpy(image)
#         target_tensor = torch.from_numpy(target)

#         # Resize the image
#         resized_image = resize(image_tensor, target_size)
#         resized_images.append(resized_image)
#         targets.append(target_tensor)

#     # Stack resized images into a single tensor
#     images = torch.stack(resized_images, dim=0)

#     # Stack targets into a single tensor
#     targets = torch.stack(targets, dim=0)

#     return images, targets

# # Now, when creating DataLoader, specify the custom collate function
# train_data = DataLoader(concatenated_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn)

# %%
from torch.utils.data import ConcatDataset
from torch.utils.data import DataLoader

dataset0 = train_data0.dataset
dataset1 = train_data1.dataset
dataset2 = train_data2.dataset
dataset3 = train_data3.dataset

# Concatenate datasets
concatenated_dataset = ConcatDataset([dataset0, dataset1, dataset2, dataset3])

# %%
len(concatenated_dataset)
# Out:
# 1256

# %%
import warnings
from typing import Dict, Mapping

import hydra
import numpy as np
import torch
from omegaconf import OmegaConf, UnsupportedValueType, DictConfig, open_dict
from torch.utils.data import BatchSampler, DataLoader, TensorDataset, RandomSampler

import super_gradients
# from super_gradients.common.abstractions.abstract_logger import get_logger
from super_gradients.common.registry.registry import register_dataloader, ALL_DATALOADERS
# from super_gradients.common.factories.collate_functions_factory import CollateFunctionsFactory
# from super_gradients.common.factories.datasets_factory import DatasetsFactory
# from super_gradients.common.factories.samplers_factory import SamplersFactory
from super_gradients.common.object_names import Dataloaders
# from super_gradients.training.datasets import ImageNetDataset
# from super_gradients.training.datasets.classification_datasets.cifar import (
#     Cifar10,
#     Cifar100,
# )
from super_gradients.training.datasets.detection_datasets import COCODetectionDataset, RoboflowDetectionDataset, YoloDarknetFormatDetectionDataset
# from super_gradients.training.datasets.detection_datasets.pascal_voc_detection import (
#     PascalVOCUnifiedDetectionTrainDataset,
#     PascalVOCDetectionDataset,
# )
from super_gradients.training.datasets.pose_estimation_datasets import COCOKeypointsDataset
from super_gradients.training.datasets.pose_estimation_datasets.rescoring_dataset import TrainRescoringDataset, ValTrainRescoringDataset

# from super_gradients.training.datasets.samplers import (
#     RepeatAugSampler,
#     DistributedSamplerWrapper,
# )
# from super_gradients.training.datasets.segmentation_datasets import (
#     CityscapesDataset,
#     CoCoSegmentationDataSet,
#     PascalVOC2012SegmentationDataSet,
#     PascalVOCAndAUGUnifiedDataset,
#     MapillaryDataset,
#     SuperviselyPersonsDataset,
# )
from super_gradients.training.utils import get_param
from super_gradients.training.utils.distributed_training_utils import (
    wait_for_the_master,
)
# from super_gradients.common.environment.ddp_utils import get_local_rank
# from super_gradients.training.utils.utils import override_default_params_without_nones
# from super_gradients.common.environment.cfg_utils import load_dataset_params
# from super_gradients.training.dataloaders.adapters import maybe_setup_dataloader_adapter
import torch.distributed as dist

def get_data_loader(config_name: str, dataset_cls: object, train: bool, dataset_params: Mapping = None, dataloader_params: Mapping = None) -> DataLoader:
    """
    Class for creating dataloaders for taking defaults from yaml files in src/super_gradients/recipes.

    :param config_name: yaml config filename of dataset_params in recipes (for example coco_detection_dataset_params).
    :param dataset_cls: torch dataset uninitialized class.
    :param train: controls whether to take
        cfg.train_dataloader_params or cfg.valid_dataloader_params as defaults for the dataset constructor
     and
        cfg.train_dataset_params or cfg.valid_dataset_params as defaults for DataLoader contructor.

    :param dataset_params: dataset params that override the yaml configured defaults, then passed to the dataset_cls.__init__.
    :param dataloader_params: DataLoader params that override the yaml configured defaults, then passed to the DataLoader.__init__
    :return: DataLoader
    """
    if dataloader_params is None:
        dataloader_params = dict()
    if dataset_params is None:
        dataset_params = dict()

    cfg = load_dataset_params(config_name=config_name)

    dataset_params = _process_dataset_params(cfg, dataset_params, train)

    local_rank = get_local_rank()
    with wait_for_the_master(local_rank):
        dataset = dataset_cls(**dataset_params)
        if not hasattr(dataset, "dataset_params"):
            dataset.dataset_params = dataset_params

    dataloader_params = _process_dataloader_params(cfg, dataloader_params, dataset, train)

    # Ensure there is no dataset in dataloader_params (Could be there if the user provided dataset class name)
    if "dataset" in dataloader_params:
        _ = dataloader_params.pop("dataset")

    dataloader = DataLoader(dataset=dataset, **dataloader_params)
    dataloader.dataloader_params = dataloader_params

    maybe_setup_dataloader_adapter(dataloader=dataloader)
    return dataloader

# %%
# @register_dataloader(Dataloaders.COCO_DETECTION_YOLO_FORMAT_TRAIN)
def coco_detection_yolo_format_train1(dataset_params: Dict = None, dataloader_params: Dict = None) -> DataLoader:
    return get_data_loader(
        config_name="coco_detection_yolo_format_base_dataset_params",
        dataset_cls=YoloDarknetFormatDetectionDataset,
        train=True,
        dataset_params=dataset_params,
        dataloader_params=dataloader_params,
    )

# %%
import torch
from torch.utils.data import ConcatDataset

# Define batch size
BATCH_SIZE = 8

# Concatenate datasets
# concatenated_dataset = ConcatDataset([dataset0, dataset1, dataset2, dataset3])

# Create a DataLoader for the concatenated dataset
concatenated_loader = coco_detection_yolo_format_train(
    dataset_params={
        'data_dir': dataset_params['data_dir'],
        'images_dir': dataset_params['train_images_dir'],
        'labels_dir': dataset_params['train_labels_dir'],
        'classes': dataset_params['classes']
    },
    dataloader_params={
        'batch_size': BATCH_SIZE,
        'num_workers': 2
    }
)
# Out:
# [2024-03-28 14:31:51] WARNING - yolo_format_detection.py - 1 images are note associated to any label file
# [2024-03-28 14:31:51] WARNING - yolo_format_detection.py - As a consequence, 314/315 images and 314/314 label files will be used.
# Caching annotations: 100%|███████████████████████████████████████████████████████████████████████| 314/314 [00:00<00:00, 9055.30it/s]

# %%
concatenated_loader.dataset.transforms
# Out:
# [DetectionMosaic('additional_samples_count': 3, 'non_empty_targets': False, 'prob': 1.0, 'input_dim': (640, 640), 'enable_mosaic': True, 'border_value': 114),
#  DetectionRandomAffine('additional_samples_count': 0, 'non_empty_targets': False, 'degrees': 10.0, 'translate': 0.1, 'scale': [0.1, 2], 'shear': 2.0, 'target_size': (640, 640), 'enable': True, 'filter_box_candidates': True, 'wh_thr': 2, 'ar_thr': 20, 'area_thr': 0.1, 'border_value': 114),
#  DetectionMixup('additional_samples_count': 1, 'non_empty_targets': True, 'input_dim': (640, 640), 'mixup_scale': [0.5, 1.5], 'prob': 1.0, 'enable_mixup': True, 'flip_prob': 0.5, 'border_value': 114),
#  DetectionHSV('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 1.0, 'hgain': 5, 'sgain': 30, 'vgain': 30, 'bgr_channels': (0, 1, 2), '_additional_channels_warned': False),
#  DetectionHorizontalFlip('additional_samples_count': 0, 'non_empty_targets': False, 'prob': 0.5),
# ...

# %%
# Define batch size
BATCH_SIZE = 8

# Concatenate datasets
concatenated_dataset = ConcatDataset([dataset0, dataset1, dataset2, dataset3])
concatenated_dataset_coco = coco_detection_yolo_format_train1()
# Shuffle the concatenated dataset
torch.manual_seed(42)  # Set seed for reproducibility
indices = torch.randperm(len(concatenated_dataset))

# Create batches manually
batched_data = []
batch_images = []
batch_targets = []
for idx in indices:
    image, target = concatenated_dataset[idx]
    batch_images.append(image)
    batch_targets.append(target)
    if len(batch_images) == BATCH_SIZE:
        # Stack images and targets to create a batch
        batch_images_tensor = torch.stack(batch_images, dim=0)
        batch_targets_tensor = torch.stack(batch_targets, dim=0)
        batched_data.append((batch_images_tensor, batch_targets_tensor))
        # Reset lists for the next batch
        batch_images = []
        batch_targets = []

# If there are remaining samples not forming a full batch, create a final batch
if len(batch_images) > 0:
    batch_images_tensor = torch.stack(batch_images, dim=0)
    batch_targets_tensor = torch.stack(batch_targets, dim=0)
    batched_data.append((batch_images_tensor, batch_targets_tensor))

# %%
#got error after setting gpu
# import torch
# from torchvision.transforms.functional import resize

# def custom_collate_fn(batch):
#     # Find the maximum height and width in the batch
#     max_height = max(sample[0].shape[0] for sample in batch)
#     max_width = max(sample[0].shape[1] for sample in batch)

#     # Define a fixed size for resizing
#     target_size = (max_height, max_width)

#     # Resize images to the maximum height and width
#     resized_images = []
#     targets = []
#     for image, target in batch:
#         # Convert the NumPy array to a PyTorch tensor for both image and target
#         image_tensor = torch.from_numpy(image)
#         target_tensor = torch.from_numpy(target)

#         # Resize the image
#         resized_image = resize(image_tensor, target_size)
#         resized_images.append(resized_image)

#         # Pad the target to match the maximum size
#         padded_target = torch.nn.functional.pad(target_tensor, (0, 0, 0, max_height - target_tensor.shape[0]))
#         targets.append(padded_target)

#     # Stack resized images into a single tensor
#     images = torch.stack(resized_images, dim=0)

#     # Stack padded targets into a single tensor
#     targets = torch.stack(targets, dim=0)

#     return images, targets

# # Now, when creating DataLoader, specify the custom collate function
# train_data = DataLoader(concatenated_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn)

# %%
# import torch
# from torchvision.transforms.functional import resize

# def custom_collate_fn(batch):
#     # Find the maximum height and width in the batch
#     max_height = 640 #max(sample[0].shape[0] for sample in batch)
#     max_width = 640 #max(sample[0].shape[1] for sample in batch)

#     # Define a fixed size for resizing
#     target_size = (max_height, max_width)

#     # Resize images to the maximum height and width
#     resized_images = []
#     targets = []
#     for image, target in batch:
#         # Convert the NumPy array to a PyTorch tensor for both image and target
#         image_tensor = torch.from_numpy(image)
#         target_tensor = torch.from_numpy(target)

#         # Resize the image
#         resized_image = resize(image_tensor, target_size)
#         resized_images.append(resized_image)

#         # Pad the target to match the maximum size
#         padded_target = torch.nn.functional.pad(target_tensor, (0, max_width - target_tensor.shape[1], 0, max_height - target_tensor.shape[0]))
#         targets.append(padded_target)

#     # Stack resized images into a single tensor
#     images = torch.stack(resized_images, dim=0)

#     # Stack padded targets into a single tensor
#     targets = torch.stack(targets, dim=0)

#     return images, targets

# # Now, when creating DataLoader, specify the custom collate function
# train_data = DataLoader(concatenated_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=custom_collate_fn)
# trainer.train(
#     model=model, 
#     training_params=train_params, 
#     train_loader=train_data, 
#     valid_loader=val_data
# )

# %%
import torch
from torch.utils.data import DataLoader
from torchvision.transforms.functional import resize

def custom_collate_fn(batch):
    max_height = 640
    max_width = 640

    target_size = (max_height, max_width)

    resized_images = []
    targets = []
    for image, target in batch:
        image_tensor = torch.from_numpy(image)
        target_tensor = torch.from_numpy(target)

        # Resize the image
        resized_image = resize(image_tensor, target_size)
        resized_images.append(resized_image)

        # Pad the target to match the maximum size
        padded_target = torch.nn.functional.pad(target_tensor.unsqueeze(0), (0, max_width - target_tensor.shape[1], 0, max_height - target_tensor.shape[0]))
        targets.append(padded_target)

    images = torch.stack(resized_images, dim=0)
    targets = torch.stack(targets, dim=0).squeeze(1)  # Remove the extra dimension

    return images, targets


# Example code snippet
image_index = torch.randn(8, 640)  # Example mask tensor
gt_class = torch.randn(8, 1, 640)    # Example tensor to index

# Ensure mask and tensor to index have the same dimensions
assert image_index.dim() == gt_class.dim() - 1, "Dimensions of mask and tensor to index do not match"

# If the mask has fewer dimensions than the tensor to index, unsqueeze to match dimensions
if image_index.dim() < gt_class.dim() - 1:
    image_index = image_index.unsqueeze(1)  # Add an additional dimension

# Now, perform the indexing operation
image_labels = gt_class[image_index]

# Continue with the rest of the code

# Assuming concatenated_dataset and BATCH_SIZE are defined elsewhere
train_data = DataLoader(concatenated_dataset, batch_size=8, shuffle=True, collate_fn=custom_collate_fn)

# %%
import torch
from super_gradients.training import models
from super_gradients.training import Trainer

DEVICE = 'cuda' if torch.cuda.is_available() else 'cpu'
model = models.get('yolo_nas_m', pretrained_weights="coco").to(DEVICE)
trainer = Trainer(experiment_name="KIKUYAIMG", ckpt_root_dir="./AugbuiltinweightsRe640")
# Out:
# [2024-03-28 14:11:00] INFO - checkpoint_utils.py - License Notification: YOLO-NAS pre-trained weights are subjected to the specific license terms and conditions detailed in
# https://github.com/Deci-AI/super-gradients/blob/master/LICENSE.YOLONAS.md
# By downloading the pre-trained weight files you agree to comply with these terms.

# %%
from super_gradients.training.losses import PPYoloELoss
from super_gradients.training.metrics import DetectionMetrics_050
from super_gradients.training.models.detection_models.pp_yolo_e import PPYoloEPostPredictionCallback

MAX_EPOCHS = 1000

train_params = {
    'silent_mode': False,
    "average_best_models":True,
    "warmup_mode": "linear_epoch_step",
    "warmup_initial_lr": 1e-6,
    "lr_warmup_epochs": 3,
    "initial_lr": 5e-4,
    "lr_mode": "cosine",
    "cosine_final_lr_ratio": 0.1,
    "optimizer": "Adam",
    "optimizer_params": {"weight_decay": 0.0001},
    "zero_weight_decay_on_bias_and_bn": True,
    "ema": True,
    "ema_params": {"decay": 0.9, "decay_type": "threshold"},
    "max_epochs": MAX_EPOCHS,
    "mixed_precision": True,
    "loss": PPYoloELoss(
        use_static_assigner=False,
        num_classes=len(dataset_params['classes']),
        reg_max=16
    ),
    "valid_metrics_list": [
        DetectionMetrics_050(
            score_thres=0.1,
            top_k_predictions=300,
            num_cls=len(dataset_params['classes']),
            normalize_targets=True,
            post_prediction_callback=PPYoloEPostPredictionCallback(
                score_threshold=0.01,
                nms_top_k=1000,
                max_predictions=300,
                nms_threshold=0.7
            )
        )
    ],
    "metric_to_watch": 'mAP@0.50'
}

# %%
trainer.train(
    model=model, 
    training_params=train_params, 
    train_loader=concatenated_dataset, 
    valid_loader=val_data
)
