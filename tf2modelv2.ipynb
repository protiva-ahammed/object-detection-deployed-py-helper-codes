# %%
# !pip uninstall Cython -y 
# !git clone --depth 1 https://github.com/tensorflow/models
# Out:
# WARNING: Skipping Cython as it is not installed.
# fatal: destination path 'models' already exists and is not an empty directory.

# %%
# %%bash
# cd ./models/research/
# protoc object_detection/protos/*.proto --python_out=.

# %%
# !pwd
# Out:
# /home/protiva

# %%
# !cd ./models/research/object_detection && protoc ./object_detection/protos/*.proto --python_out=.

# %%
# %%bash
# cd models/research/object_detection/protos/
# ls -la

# %%
import re
with open('./models/research/object_detection/packages/tf2/setup.py') as f:
    s = f.read()

with open('./models/research/setup.py', 'w') as f:
    # Set fine_tune_checkpoint path
    s = re.sub('tf-models-official>=2.5.1',
               'tf-models-official==2.8.0', s)
    f.write(s)

# %%
# !export LD_LIBRARY_PATH=/user/local/cuda-11.0/lib64:$LD_LIBRARY_PATH

# %%
# !export PROTOCOL_BUFFERS_PYTHON_IMPLEMENTATION=python

# %%
# !python models/research/object_detection/builders/model_builder_tf2_test.py
# Out:
# Traceback (most recent call last):
#   File "models/research/object_detection/builders/model_builder_tf2_test.py", line 24, in <module>
#     from object_detection.builders import model_builder
# ModuleNotFoundError: No module named 'object_detection'

# %%
# !pwd
# Out:
# /home/protiva
